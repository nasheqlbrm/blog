# %% [markdown]
# # Bear Classification
# > Using Fastai to classify bears.
#
# - toc: true
# - badges: true
# - comments: true
# - categories: [fastai, jupyter]

# %% [markdown]
# # Introduction
#
# Yada yada yada ...

# %% [markdown]
# ## Preliminaries
#
# * Install the jmd_imagescraper [library](https://github.com/joedockrill/jmd_imagescraper/tree/master/) using `!pip3 install jmd_imagescraper`
#
# * I have set FASTAI_HOME in my .bashrc so that any datasets downloaded via Fastai are stored under a different location than the default (/home/kaushik/.fastai). This is because my default location is space constrained. Feel free to omit this if step.
# ```
# export FASTAI_HOME=/data/kaushik/.fastai
# export PATH=$FASTAI_HOME:$PATH
# ```
