# %% [markdown]
# # Bear Classification
# > Using Fastai to classify bears.
#
# - toc: true
# - badges: true
# - comments: true
# - categories: [fastai, jupyter]

# %% [markdown]
# # Assemble images
#
# Install the jmd_imagescraper [library](https://github.com/joedockrill/jmd_imagescraper/tree/master/) if you don't have it already.

# %%
#collapse-output
# !pip3 install jmd_imagescraper
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached jmd_imagescraper-1.0.2-py3-none-any.whl (12 kB)
# ...
#   Using cached bs4-0.0.1.tar.gz (1.1 kB)
# ...
#      |████████████████████████████████| 115 kB 31.4 MB/s eta 0:00:01
# ...
#   Using cached pathlib-1.0.1.tar.gz (49 kB)
# ...
#   Created wheel for bs4: filename=bs4-0.0.1-py3-none-any.whl size=1273 sha256=9fb94ae12e98db21ab8d3359633dbb02e33244ef9a6a8919f8162313e16ba29a
#   Stored in directory: /home/kaushik/.cache/pip/wheels/0a/9e/ba/20e5bbc1afef3a491f0b3bb74d508f99403aabe76eda2167ca
# ...
#   Created wheel for pathlib: filename=pathlib-1.0.1-py3-none-any.whl size=14347 sha256=65718225c4be3c63fa6524eec688a97b636e60e7a7dc6b65c0d56ed3423214db
#   Stored in directory: /home/kaushik/.cache/pip/wheels/6e/96/b8/10037fe231e23970bac58361d7c93571ab983a7bbc55e68550
# Successfully built bs4 pathlib
# ...
# WARNING: You are using pip version 20.3.3; however, version 20.3.4 is available.
# ...
